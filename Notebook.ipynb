# %% [markdown]
# # Loading in the data

# %%
import pandas as pd
import numpy as np
import os, random, math, glob
from IPython.display import Image as IM
from IPython.display import clear_output
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [16, 10]

# %%
df_train = pd.read_csv('Train.csv')
df = pd.read_csv('Test.csv')
df_train.head()
# Out:
#                ward  total_households  total_individuals     target     dw_00  \
# 0  41601001: Ward 1        1674.45058         5888.20750  16.773757  0.933841
# 1  41601002: Ward 2        1736.99230         6735.33812  21.496661  0.696940
# 2  41601003: Ward 3        2403.57591         7273.04995  10.931425  0.810545
# 3  41601004: Ward 4        1740.78737         5734.49046  23.119257  0.659914
# 4  41601005: Ward 5        1730.51451         6657.23835  13.652252  0.950575
#
#       dw_01     dw_02     dw_03     dw_04     dw_05  ...     pw_03     pw_04  \
# 0  0.000846  0.005490  0.000676  0.000000  0.001372  ...  0.002848  0.007537
# 1  0.001253  0.004402  0.000000  0.002301  0.001323  ...  0.014566  0.057127
# 2  0.004517  0.008891  0.003986  0.007735  0.000956  ...  0.057560  0.010358
# 3  0.000000  0.006129  0.000000  0.000813  0.037245  ...  0.000000  0.000669
# 4  0.000655  0.001473  0.000598  0.006999  0.000818  ...  0.004859  0.001290
#
# ...

# %%
df.shape
# Out:
# (1013, 62)

# %% [markdown]
# # Modeling

# %%
df_train = df_train.drop(['ADM4_PCODE', 'ward'], axis = 1)
df_test = df.drop(['ADM4_PCODE', 'ward'], axis = 1)

# %%
y = df_train['target']
df_train = df_train.drop('target', axis = 1)

# %%
data_dmatrix = xgb.DMatrix(data=df_train,label=y)

# %%
#from sklearn.model_selection import train_test_split

# %%
xg_reg = xgb.XGBRegressor(objective ='reg:squarederror')

# %%
xg_reg.fit(df_train,y)
preds = xg_reg.predict(df_test)

# %%
#rmse = np.sqrt(mean_squared_error(y_test, preds))
#print("RMSE: %f" % (rmse))

# %%
df
# Out:
#                     ward  total_households  total_individuals     dw_00  \
# 0       21001001: Ward 1        2504.95194         8745.15151  0.947257
# 1       21001002: Ward 2        2080.27718         7258.11764  0.844993
# 2       21001003: Ward 3        1106.62639         5919.13170  0.651380
# 3       21001004: Ward 4        2175.56096        10280.57452  0.410837
# 4       21001005: Ward 5        1270.83883         6018.34202  0.942851
# ...                  ...               ...                ...       ...
# 1008  19100107: Ward 107       16076.89903        43296.51372  0.668295
# 1009  19100108: Ward 108       17470.24004        53538.12816  0.483111
# 1010  19100109: Ward 109        9467.25336        40332.11708  0.579036
# 1011  19100110: Ward 110        6111.31195        27793.92916  0.623537
# 1012  19100111: Ward 111        9746.91152        37494.86375  0.689628
#
#          dw_01     dw_02     dw_03     dw_04     dw_05     dw_06  ...  \
# ...

# %%
df['preds'] = xg_reg.predict(df_test)

# %%
df[['ward', 'preds']].to_csv('predictions.csv', index=False)

# %%
df[['ward', 'preds']]
# Out:
#                     ward      preds
# 0       21001001: Ward 1  17.666430
# 1       21001002: Ward 2  15.072925
# 2       21001003: Ward 3  20.739376
# 3       21001004: Ward 4  17.038681
# 4       21001005: Ward 5  20.164087
# ...                  ...        ...
# 1008  19100107: Ward 107   6.447568
# 1009  19100108: Ward 108  21.770216
# 1010  19100109: Ward 109  17.875971
# 1011  19100110: Ward 110  13.953951
# 1012  19100111: Ward 111  16.512848
#
# [1013 rows x 2 columns]
